# %%
print("Hello world")
# Out:
# Hello world

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
git push https://YOUR_TOKEN@github.com/Feden-Duliente/Testing.git main

# %%
print("Testing")
